# %% [markdown]
# <a href="https://colab.research.google.com/github/indhu1122/indhu/blob/main/experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# load the dataset
dataset=pd.read_csv("/content/details.csv")
#printing the dataset
dataset
# Out:
#     Age   Salary
# 0  30.0  40000.0
# 1  25.0  30000.0
# 2   NaN  50000.0
# 3  35.0      NaN
# 4  40.0  45000.0
# 5   NaN  35000.0
# 6   NaN      NaN
# 7  19.0  20000.0
# 8  45.0  55000.0
# 9  20.0      NaN

# %%
#extraction of independent and dependent variables
X=dataset.iloc[:,:-1].values
Y=dataset.iloc[:,-1].values
print("independent variable(X):",X)
print("dependent variable(Y):",Y)
# Out:
# independent variable(X): [[30.]
#  [25.]
#  [nan]
#  [35.]
#  [40.]
#  [nan]
#  [nan]
#  [19.]
#  [45.]
#  [20.]]
# dependent variable(Y): [40000. 30000. 50000.    nan 45000. 35000.    nan 20000. 55000.    nan]

# %%
#dealing with missing data
from sklearn.impute import SimpleImputer
#Replacing the missing value using transform method
imp=SimpleImputer(missing_values=np.nan,strategy="mean")
X=imp.fit_transform(X)
Y=Y.reshape(-1,1)
Y=imp.fit_transform(Y)
Y=Y.reshape(-1)
print(X)
print(Y)
# Out:
# [[30.        ]
#  [25.        ]
#  [30.57142857]
#  [35.        ]
#  [40.        ]
#  [30.57142857]
#  [30.57142857]
#  [19.        ]
#  [45.        ]
#  [20.        ]]
# [40000.         30000.         50000.         39285.71428571
#  45000.         35000.         39285.71428571 20000.
#  55000.         39285.71428571]

# %%
#convert X and Y to DataFrames
X_df=pd.DataFrame(X,columns=dataset.columns[:-1])
Y_df=pd.DataFrame(Y,columns=[dataset.columns[-1]])
#combine X and Y side by side using pandas.concat
combined_data=pd.concat([X_df,Y_df],axis=1)
#Display the combined data
print("combined Data:")
print(combined_data)
# Out:
# combined Data:
#          Age        Salary
# 0  30.000000  40000.000000
# 1  25.000000  30000.000000
# 2  30.571429  50000.000000
# 3  35.000000  39285.714286
# 4  40.000000  45000.000000
# 5  30.571429  35000.000000
# 6  30.571429  39285.714286
# 7  19.000000  20000.000000
# 8  45.000000  55000.000000
# 9  20.000000  39285.714286

# %%
#convert the combined_data to a DataFrames
combined_df=pd.DataFrame(combined_data,columns=list(dataset.columns))
combined_df.to_excel("/content/combined_data.xlsx",index=False)
print("combined DataFrame:")
print("combined_df.head()")
# Out:
# combined DataFrame:
# combined_df.head()
